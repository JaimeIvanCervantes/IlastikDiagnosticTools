# %%
# %matplotlib inline

from src.trackingCsvDiagnostics import TrackingDiagnostics
import numpy as np
import matplotlib

# set the plot size
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# Instance TrackingDiagnositcs class
td = TrackingDiagnostics('data/GMR_71G01_AE_01_TrpA_Rig2Plate14BowlC_20110707T154934-exported_data_table.csv')

# Plot color tracks for every object
td.plotTracks()

# Plot lineage ID's (You can clearly see appearing and dissapearing IDs)
td.plotLineageIds()

# Plot object number per frame
td.plotObjectNum()

# plot bounding rectangles for first frame (mergers in red)
td.plotBoundingRect(0)
